# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\bunyo\Downloads\Telegram Desktop\cars2018.csv")

# %%
df
# Out:
#                                           model  model_index  displacement  \
# 0                                     Acura NSX           57           3.5
# 1                                 ALFA ROMEO 4C          410           1.8
# 2                                   Audi R8 AWD           65           5.2
# 3                                   Audi R8 RWD           71           5.2
# 4                            Audi R8 Spyder AWD           66           5.2
# ...                                         ...          ...           ...
# 1139              TOYOTA LAND CRUISER WAGON 4WD           86           5.7
# 1140                         TOYOTA SEQUOIA 4WD           37           5.7
# 1141                     TOYOTA SEQUOIA 4WD FFV           33           5.7
# 1142  Volvo Cars of North America, LLC XC90 AWD           53           2.0
# 1143  Volvo Cars of North America, LLC XC90 AWD           52           2.0
#
# ...
