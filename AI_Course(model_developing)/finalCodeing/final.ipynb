# %%
import numpy as np

# %%
# berilgan sozdagi unlini tashab yuboradi (aoieu)

# %%
class func:
    def __init__(self,num):
        self.num = num

    def f(self):
        return [x for x in self.num if x > 9 and x <= 99 and x%2 ==0]

# %%
result = func([-2,-29,0,18,25,88,1000,99,100])
result.f()
# Out:
# [18, 88]
