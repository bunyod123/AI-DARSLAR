# %%
import os
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\git_dataset\synthetic_coffee_health_10000.csv")

# %%
# AI_Course(model_developing)/4-dars/joy

# %%
out_folder = 'AI_Course(model_developing)/4-dars/joy'
os.makedirs(out_folder,exist_ok=True)
