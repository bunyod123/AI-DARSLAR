# %% [markdown]
# # Data preproccesing savollar

# %%
#  basic question numer one
   #  data preprocessing nimaga kerak
      #  data preprocessing qilinmasa nima boladi?
      #  data preprocessing qilishda eng qiyin data turi qaysi?
      #  data preprocessing qilishda eng oson data turi qaysi?
      #  qanday datani preprocessiong qilish shartmas?
      #  data preproccesnig model aniqligiga qandya tasir o'tkazadi

# %%
#   basic question numer two
    #  Missing value larni qanday usullar bilan toldiriladi?
        #  qachon drop qilish kerak?
        #  mean va median nima farqi bor?
        #  outlier ko'p bolsa nima qilish kerak?
        #  nechta usuli bor?
        #  missing value ni toldirishni oson usuli?

# %%
#   basic question numer three
    #  Encodingni qanday usulari bor?
        #  One hot encoding qachon ishlatiladi
        #  Label encoding bilan One Hotni nima farqi bor?
        #  Target encoding nimaga kam ishlatiladi?
        #  Frequency ecodingni kamchiligi nima?
        #  Eng oson encoding usuli qaysi?

# %%
#  basic question numer four
    #  Feature scalingni nimaga ishlatamiz?
        #  Scalingni eng qiyin suli qaysi?
        #  Robust bilan standart scaling oxshashligi nima?
        #  Min max scaling afzalligi nima?
        #  scaling qimasa model qanday ishlaydi?
        #  target datani scale qisa nima boladi?

# %%
#  basic question numer five?
    #  train test splitni vazifasi nima?
        #  data qanday foizda split bolgani yaxshi?
        #  random_state vazifasi nima?
        #  train test splitga alternative usul qaysi?
        #  bir biridan nima farqi bor?
        #  data juda kichik bosa qaysini ishlatgan yaxshi?
