# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\git_dataset\9. Sales-Data-Analysis.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
def tozalash(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='object':
                df[col].fillna(df[col].mode()[0],inplace=True)
            else:
                df[col].fillna(df[col].mean(),inplace=True)
    return df

# %%
df = tozalash(df)

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
minmax = MinMaxScaler()
labeling = LabelEncoder()

# %%
def encodla(df):
    for col in df.columns:
        if df[col].dtype=='object':
            if df[col].nunique()<=5:
                dummies=pd.get_dummies(df[col],prefix=col, dtype=int)
                df=pd.concat([df.drop(columns=[col]),dummies],axis=1)
            else:
                df[col]=labeling.fit_transform(df[col])
    return df

# %%
df= encodla(df)

# %%
def scale_qil(df):
    num_col=df.select_dtypes(include=['int64','int32','float64']).columns.drop('Quantity')
    df[num_col]=minmax.fit_transform(df[num_col])
    return df

# %%
df = scale_qil(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Order ID                     254 non-null    float64
#  1   Date                         254 non-null    float64
#  2   Price                        254 non-null    float64
#  3   Quantity                     254 non-null    float64
#  4   Manager                      254 non-null    float64
#  5   Product_Beverages            254 non-null    float64
#  6   Product_Burgers              254 non-null    float64
#  7   Product_Chicken Sandwiches   254 non-null    float64
#  8   Product_Fries                254 non-null    float64
#  9   Product_Sides & Other        254 non-null    float64
#  10  Purchase Type_Drive-thru     254 non-null    float64
#  11  Purchase Type_In-store       254 non-null    float64
# ...

# %%
from sklearn.linear_model import LinearRegression
lin_Reg = LinearRegression()
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
x = df.drop('Quantity', axis=1)
y = df['Quantity']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=46)

# %%
lin_Reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred1 = lin_Reg.predict(x_test)

# %%
print(r2_score(y_test,pred1))
# Out:
# 0.9638602353799136

# %% [markdown]
# # Tree regression

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()

# %%
tree_reg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred2 = tree_reg.predict(x_test)

# %%
print(r2_score(y_test,pred2))
# Out:
# 0.9890675602854934

# %%
from tabulate import tabulate

# %%
results=[
    ['Linear Regression',0.9636],
    ['Decision Tree',0.9890]]

headers=['Algorithm','Accuracy_score']
tables=tabulate(results, headers=headers, tablefmt='grid',floatfmt='.4f')

print(tables)
# Out:
# +-------------------+------------------+
# | Algorithm         |   Accuracy_score |
# +===================+==================+
# | Linear Regression |           0.9636 |
# +-------------------+------------------+
# | Decision Tree     |           0.9890 |
# +-------------------+------------------+

# %%
natija = [
    ['Regrassion', 344,343,43,00],
    ['Classification', 23,232,44,11]
]
heads = ['model nomi', 'accuracy', 'result', 'f1','support']
table = tabulate(natija, headers=heads, tablefmt='fancy_grid',floatfmt='.6f')
print(table)
# Out:
# ╒════════════════╤════════════╤══════════╤══════╤═══════════╕
# │ model nomi     │   accuracy │   result │   f1 │   support │
# ╞════════════════╪════════════╪══════════╪══════╪═══════════╡
# │ Regrassion     │        344 │      343 │   43 │         0 │
# ├────────────────┼────────────┼──────────┼──────┼───────────┤
# │ Classification │         23 │      232 │   44 │        11 │
# ╘════════════════╧════════════╧══════════╧══════╧═══════════╛

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import r2_score,root_mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score

# %%
labeling = LabelEncoder()
scaler = MinMaxScaler()

# %%
df = pd.read_csv(r"C:\Users\bunyo\OneDrive\Desktop\kaggleDataSet\House Price Prediction Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   object
#  7   Condition  2000 non-null   object
#  8   Garage     2000 non-null   object
#  9   Price      2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
def Nan_Toldiruvchi(data):
    for col in data.columns:
        if data[col].isnull().any():
            if data[col].dtype == 'object':
                data[col].fillna(data[col].mode()[0],inplace = True)
            else:
                data[col].fillna(data[col].mean(),inplace = True)
    return data

# %%
def Encodings(data):
    object_cols = data.select_dtypes(include =['object']).columns
    for cols in object_cols:
        data[cols] = labeling.fit_transform(data[cols])
    return data

# %%
Encodings(df)
# Out:
#             Id      Area  Bedrooms  Bathrooms    Floors  YearBuilt  Location  \
# 0    -1.731185 -1.101471  1.401791   1.305568  1.244151   0.238155         0
# 1    -1.729453  1.147485  1.401791   1.305568  1.244151  -0.095942         0
# 2    -1.727721  0.622317 -0.704581  -0.498326  1.244151  -0.652770         0
# 3    -1.725989 -1.405759  0.699667  -0.498326  0.008035  -1.655061         2
# 4    -1.724257  1.652574 -1.406705   1.305568  0.008035   0.377363         0
# ...        ...       ...       ...        ...       ...        ...       ...
# 1995  1.724257  1.705091  1.401791   1.305568  1.244151  -1.070391         2
# 1996  1.725989  0.200638  1.401791  -0.498326 -1.228081   1.602385         2
# 1997  1.727721 -1.331618  1.401791  -1.400273  0.008035  -1.627219         1
# 1998  1.729453  0.985301 -0.002457  -1.400273  0.008035  -0.708453         3
# 1999  1.731185  0.156616  1.401791  -1.400273  1.244151  -1.627219         2
#
#       Condition  Garage   Price
# ...

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()

# %%
def scaling(data):
    num_cols = data.select_dtypes(exclude = ['object']).columns.drop('Price')
    
    data[num_cols] = std.fit_transform(data[num_cols])
    return data

# %%
scaling(df)
# Out:
#             Id      Area  Bedrooms  Bathrooms    Floors  YearBuilt  Location  \
# 0    -1.731185 -1.101471  1.401791   1.305568  1.244151   0.238155 -1.274332
# 1    -1.729453  1.147485  1.401791   1.305568  1.244151  -0.095942 -1.274332
# 2    -1.727721  0.622317 -0.704581  -0.498326  1.244151  -0.652770 -1.274332
# 3    -1.725989 -1.405759  0.699667  -0.498326  0.008035  -1.655061  0.486403
# 4    -1.724257  1.652574 -1.406705   1.305568  0.008035   0.377363 -1.274332
# ...        ...       ...       ...        ...       ...        ...       ...
# 1995  1.724257  1.705091  1.401791   1.305568  1.244151  -1.070391  0.486403
# 1996  1.725989  0.200638  1.401791  -0.498326 -1.228081   1.602385  0.486403
# 1997  1.727721 -1.331618  1.401791  -1.400273  0.008035  -1.627219 -0.393965
# 1998  1.729453  0.985301 -0.002457  -1.400273  0.008035  -0.708453  1.366771
# 1999  1.731185  0.156616  1.401791  -1.400273  1.244151  -1.627219  0.486403
#
#       Condition    Garage   Price
# ...

# %%
from sklearn.preprocessing import StandardScaler # yoki MinMaxScaler

def scaling1(df):
    data = df.copy() # Asl ma'lumotni buzmaslik uchun nusxa
    
    # 1. Scaler obyektini yaratish
    scaler = StandardScaler()
    
    # 2. Raqamli ustunlarni tanlash (Price'dan tashqari)
    # errors='ignore' -> Agar Price ustuni bo'lmasa, xato bermaydi
    num_cols = data.select_dtypes(exclude=['object']).columns.drop('Price', errors='ignore')
    
    # 3. Barcha ustunlarni BIRDANIGA (batch) shkalalash
    # Bu usul 2D array xatosini oldini oladi va tez ishlaydi
    data[num_cols] = scaler.fit_transform(data[num_cols])
    
    return data

# Ishlatilishi:
# scaled_df = scaling(df)

# %%
from sklearn.linear_model import LinearRegression

# %%
Lin_Reg = LinearRegression()
Dec_Tree = DecisionTreeRegressor()

# %%
x = df.drop('Price',axis=1)
y = df['Price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=99)

# %%
Lin_Reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = Lin_Reg.predict(x_test)

# %%
print(r2_score(y_test,pred))
# Out:
# 0.002477656675885731

# %%
Dec_Tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred1 = Dec_Tree.predict(x_test)

# %%
print(r2_score(y_test,pred1))
# Out:
# -0.9551034072464797

# %%
from tabulate import tabulate

# %%
heads = ['Algorithms','Natija','Rating']
results = [['Linear Regression',0.1222,9],
           ['DecisionTreeRegressor',0.9566,1],
           ['Random Forest',0.122212, 4]
           ]

# %%
table = tabulate(results,headers=heads,tablefmt='fancy_grid',floatfmt='0.3f')

# %%
print(table)
# Out:
# ╒═══════════════════════╤══════════╤══════════╕
# │ Algorithms            │   Natija │   Rating │
# ╞═══════════════════════╪══════════╪══════════╡
# │ Linear Regression     │    0.122 │        9 │
# ├───────────────────────┼──────────┼──────────┤
# │ DecisionTreeRegressor │    0.957 │        1 │
# ├───────────────────────┼──────────┼──────────┤
# │ Random Forest         │    0.122 │        4 │
# ╘═══════════════════════╧══════════╧══════════╛
